# %% [markdown]
# # Direct Prompt Injection
#
# Override system prompts, role confusion, delimiter attacks - the #1 LLM vulnerability.
#
# > **Status**: Placeholder - content coming soon

# %%
# TODO: implement
