# %% [markdown]
# # Build a Vulnerable LLM App
#
# Build an intentionally vulnerable chatbot, then exploit it - DVWA for LLMs.
#
# > **Status**: Placeholder - content coming soon

# %%
# TODO: implement
