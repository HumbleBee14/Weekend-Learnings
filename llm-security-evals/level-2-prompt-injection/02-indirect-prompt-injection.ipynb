# %% [markdown]
# # Indirect Prompt Injection
#
# Malicious instructions hidden in retrieved docs, emails, websites - stored XSS for LLMs.
#
# > **Status**: Placeholder - content coming soon

# %%
# TODO: implement
